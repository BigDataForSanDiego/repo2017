# %%
import pandas as pd
import numpy as np
import datetime as dt
import matplotlib.pyplot as plt
import matplotlib.dates as mdates

# %%
file1 = 'drought_data.csv'
file2 = 'Trended_3-4-50_Chronic_Disease.csv'
file3 = 'Smoke_Fire_Flames_Death_2010-2013.csv'
file4 = 'Drowning_Deaths_2010-2013.csv'
file5 = 'indicator_bacteria_tests_datasd.csv'
file6 = 'Suicide_Death_2010-2013.csv'

# %%
df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)
df5 = pd.read_csv(file5)
df6 = pd.read_csv(file6)

# %%
dates = df1.ValidStart
x = [dt.datetime.strptime(d,'%Y-%m-%d').date() for d in dates]
#print(dates[:10])
y0 = df1.D0
y1 = df1.D1
y2 = df1.D2
y3 = df1.D3
y4 = df1.D4

#plt.gca().xaxis.set_major_formatter(mdates.DateFormatter('%Y-%m-%d'))
#plt.gca().xaxis.set_major_locator(mdates.DayLocator())
#plt.plot(x,y0, color='white')
#plt.plot(x,y1, color='yellow')
#plt.plot(x,y2, color='purple')
plt.plot(x,y3, color='orange')
plt.xlabel('Year')
plt.ylabel('Severity Percentage')
plt.title('San Diego County Drought Severity (D3)')
#plt.plot(x,y4, color='red')
#plt.gcf().autofmt_xdate()

plt.show()

# %%
plt.plot(x,y2, color='blue')
plt.xlabel('Year')
plt.ylabel('Severity Percentage')
plt.title('San Diego County Drought Severity (D2)')
plt.show()

# %%
SD_county = df2[df2['Geography']=='San Diego County '] #NOTE THE SPACE AT END!!!
year = SD_county['Year']
asthma_deaths = SD_county['Asthma Deaths']
CHD_deaths = SD_county['CHD Deaths']
stroke_deaths = SD_county['Stroke Deaths']
cancer_deaths = SD_county['Cancer Deaths']
diabetes_deaths = SD_county['Diabetes Deaths']
total_deaths = SD_county['Total Deaths (All Causes)']
#print(year)

plt.plot(year,cancer_deaths)
plt.xlabel('Year')
plt.ylabel('Cancer Deaths')
plt.title('San Diego County Cancer Deaths')
plt.show()

# %%
SD_county_fire = df3[df3['RegionName']=='COUNTY']
year_fire = SD_county_fire['YEAR']
smoke_related_fire_deaths = SD_county_fire['Total_Cases']
#print(year_fire)

#plt.plot(year_fire,smoke_related_fire_deaths)
#plt.show()

# %%
SD_county_drowning = df4[df4['RegionName']=='COUNTY']
year_drowning = SD_county_drowning.YEAR.astype(int)
drowning_deaths = SD_county_drowning.Total_Cases.astype(int)

#print(year_drowning)
#print(drowning_deaths)

#plt.plot(year_drowning,drowning_deaths)
#plt.show()

# %%
#print(df5.head())
year_bacteria = df5['SAMPLE_DATE']
t_coliform = df5['T_COLIFORM']=='P'
t_coliform.replace(to_replace='A',value=0, inplace=True)
t_coliform.replace(to_replace='P',value=1, inplace=True)
t_coliform = df5['T_COLIFORM']=='1'

#print(t_coliform.head())
#print(year_bacteria.head())

e_coli = df5['E_COLI']
#print(e_coli.head())
e_coli.replace(to_replace='A',value=0, inplace=True)
e_coli.replace(to_replace='P',value=1, inplace=True)
e_coli = df5['E_COLI']=='1'
#print(e_coli.head())

#plt.bar(year_bacteria,t_coliform)
#plt.show()

# %%
SD_county_suicide = df6[df6['RegionName']=='COUNTY']
year_suicide = SD_county_suicide['YEAR']
suicide_deaths = SD_county_suicide['Total_Cases']

#plt.plot(year_suicide,suicide_deaths)
#plt.show()
